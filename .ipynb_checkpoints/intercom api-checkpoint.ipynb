# %%
from intercom import Intercom
Intercom.app_id = 'yb8sxeop'
Intercom.api_key = '7ab67c8504401831c5898148de01091b09af936f'

# %%
from intercom import User
user_all = []
for user in User.all():
    user_all.append(user)

# %%
def is_active_user(last_impression_at,dates_determine_active=30):
    
    '''
    1. input user's last_impression_at timestamp if user log in with in 30 days then this user is active
    2. if user had logged once in X days(dates_determine_active) then this user is defined to be active. 
    '''
    
    if last_impression_at == None:
        print 'No last_impression_at'
        return False
    
    import datetime 
    date_now = datetime.datetime.now().date()
    active_days = date_now - datetime.timedelta(seconds=dates_determine_active*24*60*60)
    
    date_from_timestamp = datetime.datetime.fromtimestamp(float(last_impression_at)).date()
    if fifteen_days_earlier <= date_from_timestamp <= date_now:
        return True
    else:
        return False

# %%
def is_viewsy_user(email_address):
    if '@viewsy.com' not in email_address:
        return False
    else:
        return True

# %%
from datetime import datetime
for user in user_all:
    if is_active_user(user['last_impression_at']) and not is_viewsy_user(user['email']):
        print user['email']
        print 'total session count:',user["session_count"]
# Out:
# No last_impression_at
# ms@rainmaking.co.uk
# total session count: 30

# %%
# testing 
for i in sorted(user_all, key=lambda x:x['session_count'], reverse=True):
    print i['user_id'],'--',i['session_count']
    print ''
# Out:
# 1 -- 1117
#
# 726 -- 1062
#
# 6 -- 685
#
# 5 -- 591
#
# 2 -- 507
#
# 732 -- 350
#
# 3 -- 274
#
# 1078 -- 240
#
# 16 -- 239
#
# 7 -- 144
#
# 1112 -- 92
#
# 1086 -- 78
#
# 8 -- 74
#
# 20 -- 70
#
# 727 -- 66
#
# 1081 -- 56
#
# 1052 -- 55
#
# 4 -- 55
#
# 33 -- 51
#
# 793 -- 48
#
# 45 -- 43
#
# 14 -- 42
#
# 715 -- 40
#
# 792 -- 39
#
# 736 -- 36
#
# 737 -- 36
#
# 791 -- 33
#
# 754 -- 32
#
# 734 -- 30
#
# 52 -- 30
#
# 13 -- 29
#
# 1013 -- 24
#
# 1035 -- 24
#
# 18 -- 23
#
# 517 -- 21
#
# 28 -- 21
#
# 1033 -- 19
#
# 705 -- 18
#
# 1057 -- 18
#
# 15 -- 17
#
# 1127 -- 16
#
# 12 -- 16
#
# 17 -- 15
#
# 794 -- 13
#
# 1028 -- 13
#
# 1034 -- 12
#
# 744 -- 11
#
# 1076 -- 11
#
# 729 -- 10
#
# 1075 -- 10
#
# 30 -- 10
#
# 35 -- 10
#
# 54 -- 9
#
# 733 -- 8
#
# 731 -- 8
#
# 522 -- 7
#
# 777 -- 7
#
# 1066 -- 7
#
# 21 -- 7
#
# 34 -- 7
#
# 768 -- 6
#
# 783 -- 6
#
# 786 -- 6
#
# 1011 -- 6
#
# 805 -- 6
#
# 41 -- 6
#
# 1012 -- 5
#
# 525 -- 5
#
# 771 -- 5
#
# 1077 -- 5
#
# 1099 -- 5
#
# 1114 -- 5
#
# 38 -- 5
#
# 49 -- 5
#
# 43 -- 5
#
# 56 -- 5
#
# 527 -- 4
#
# 738 -- 4
#
# 784 -- 4
#
# 765 -- 4
#
# 785 -- 4
#
# 797 -- 4
#
# 1111 -- 4
#
# 22 -- 4
#
# 773 -- 3
#
# 772 -- 3
#
# 803 -- 3
#
# 1031 -- 3
#
# 27 -- 3
#
# 42 -- 3
#
# 55 -- 3
#
# 735 -- 2
#
# 774 -- 2
#
# 775 -- 2
#
# 769 -- 2
#
# 767 -- 2
#
# 749 -- 2
#
# 804 -- 2
#
# 815 -- 2
#
# 816 -- 2
#
# 1062 -- 2
#
# 1063 -- 2
#
# 1070 -- 2
#
# 46 -- 2
#
# 53 -- 2
#
# 19 -- 2
#
# 26 -- 2
#
# 31 -- 2
#
# 32 -- 2
#
# 36 -- 2
#
# 44 -- 2
#
# 37 -- 2
#
# 39 -- 2
#
# 770 -- 1
#
# 743 -- 1
#
# 1038 -- 1
#
# 1059 -- 1
#
# 1069 -- 1
#
# 1071 -- 1
#
# 29 -- 1
#
# 9 -- 1
#
# 40 -- 1
#
# 10 -- 1
#
# 11 -- 1
#
# 47 -- 1
#
# 48 -- 1
#
# 50 -- 1
#
# 51 -- 1
#
# 23 -- 1
#
# 24 -- 1
#
# 25 -- 1
#
# None -- 0

# %%
import json
print json.dumps(user_all[1],indent=1)
# Out:
# {
#  "user_id": "726",
#  "name": "Jasper Story",
#  "last_seen_ip": "213.246.135.57",
#  "unsubscribed_from_emails": false,
#  "created_at": 1336741934,
#  "session_count": 1062,
#  "company_ids": [
#   "1",
#   "25",
#   "33"
#  ],
#  "location_data": {
#   "region_code": "H9",
#   "region_name": "London, City of",
#   "latitude": 51.5142,
#   "longitude": -0.0931,
#   "country_name": "United Kingdom",
#   "postal_code": "",
#   "continent_code": "EU",
#   "country_code": "GBR",
#   "city_name": "London",
#   "timezone": "Europe/London"
#  },
#  "email": "jasper@viewsy.com",
#  "avatar_url": "https://graph.facebook.com/61213599/picture?width=24&height=24",
#  "last_impression_at": 1393500868,
#  "custom_data": {},
#  "intercom_id": "514cce6fbaf0ba217b024fb6",
#  "last_seen_user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/33.0.1750.117 Safari/537.36",
#  "social_profiles": [
#   {
#    "url": "http://www.facebook.com/jasper.story",
#    "username": "jasper.story",
#    "type": "facebook",
#    "id": "61213599"
#   },
#   {
#    "url": "http://gravatar.com/viewsy",
#    "username": "viewsy",
#    "type": "gravatar",
#    "id": "40855831"
#   },
#   {
#    "url": "http://vimeo.com/user14469124",
#    "username": "user14469124",
#    "type": "vimeo",
#    "id": "14469124"
#   }
#  ]
# }
